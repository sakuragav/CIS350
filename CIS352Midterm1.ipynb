# %% [markdown]
# <a href="https://colab.research.google.com/github/sakuragav/CIS350/blob/Assignments/CIS352Midterm1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import the data set as a pandas Dataframe. \
# Compute the mean annual mileage for the different driving experience groups.\
# \
# Based on part (ii), do the mean for different groups in the “driving experience” vary too widely? Justify. \
# \
# Compute the mean credit score for each income group. \
# \
# Based on part (iv), do the mean credit scores for each group differ widely? Justify.\
# \
# Group the data by “outcome” and then calculate the mean “annual mileage”
# for each group. Make sure to include your code and output.

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/siglimumuni/Datasets/master/customer-data.csv"
customer = pd.read_csv(url)
customer_df = pd.DataFrame(customer)
customer_df.head()
# Out:
#        id    age  gender      race driving_experience    education  \
# 0  569520    65+  female  majority               0-9y  high school
# 1  750365  16-25    male  majority               0-9y         none
# 2  199901  16-25  female  majority               0-9y  high school
# 3  478866  16-25    male  majority               0-9y   university
# 4  731664  26-39    male  majority             10-19y         none
#
#           income  credit_score  vehicle_ownership vehicle_year  married  \
# 0    upper class      0.629027               True   after 2015    False
# 1        poverty      0.357757              False  before 2015    False
# 2  working class      0.493146               True  before 2015    False
# 3  working class      0.206013               True  before 2015    False
# 4  working class      0.388366               True  before 2015    False
#
#    children  postal_code  annual_mileage vehicle_type  speeding_violations  \
# ...

# %%
from numpy import median, mean
customer_df.groupby(['driving_experience']).mean(['annual_mileage'])
# Out:
#                                id  credit_score  vehicle_ownership   married  \
# driving_experience
# 0-9y                496940.238244      0.463657           0.591218  0.354674
# 10-19y              504158.957563      0.512155           0.694453  0.481661
# 20-29y              501271.497404      0.566321           0.798018  0.636149
# 30y+                499624.831749      0.599876           0.856464  0.753802
#
#                     children   postal_code  annual_mileage  \
# driving_experience
# 0-9y                0.545609  19701.781586    12249.131670
# 10-19y              0.680206  19694.941801    11791.275168
# 20-29y              0.830580  20636.537046    11144.181256
# 30y+                0.910646  19387.604563    10694.968553
#
#                     speeding_violations      DUIs  past_accidents   outcome
# driving_experience
# 0-9y                           0.000000  0.000000        0.000000  0.628045
# ...
