# %% [markdown]
# <a href="https://colab.research.google.com/github/sakuragav/CIS350/blob/Assignments/CIS352Assignment6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install pyspark

from pyspark.sql import SparkSession

# Create SparkSession
spark = SparkSession.builder.appName("RDDAssignment").getOrCreate()

# %%
lst = list(range(0,101))
rdd = spark.sparkContext.parallelize(lst)
even = rdd.filter(lambda x: x % 2 == 0)
even.collect()

# %%
from pyspark.sql import SparkSession
spark2 = SparkSession.builder.appName('Question2').getOrCreate()

from google.colab import files
files.upload()

rdd = spark2.sparkContext.textFile("SampleBigFile.txt")
# Out:
#      <input type="file" id="files-a2c18a9a-04e0-4553-9cc5-8e11c6c74a8b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a2c18a9a-04e0-4553-9cc5-8e11c6c74a8b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
rdd2 = rdd.flatMap(lambda x: x.split(" "))
rdd3 = rdd2.map(lambda x: (x,1))
rdd4 = rdd3.reduceByKey(lambda a,b: a+b)
rdd5 = rdd4.filter(lambda x: x[0] == 'Hadoop')
for element in rdd5.collect():
  print(element)
# Out:
# ('Hadoop', 1720320)

# %%
from pyspark.sql import SparkSession
spark3 = SparkSession.builder.appName('Question3').getOrCreate()

from google.colab import files
files.upload()

rdd = spark2.sparkContext.textFile("users.txt")
# Out:
#      <input type="file" id="files-4a091f5a-8929-4c6c-8d6e-c8750448604f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4a091f5a-8929-4c6c-8d6e-c8750448604f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
rdd2 = rdd.map(lambda x: (x.split('|')[2],1)).reduceByKey(lambda x,y: x+y)
for element in rdd2.collect():
  print(element)
# Out:
# ('M', 670)
# ('F', 273)
